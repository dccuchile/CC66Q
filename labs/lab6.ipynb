# %% [markdown]
# # Lab 6: Transformers y BERT.

# %% [markdown]
# # Actividad
#
# Basándose en el tutorial 6 construya clasificadores de texto utilizando BERT. Estos clasificadores serán para un dataset de [reviews de amazon en español](https://huggingface.co/datasets/SetFit/amazon_reviews_multi_es). Contiene el texto de la review de un producto en una escala de un producto nada recomendable (0) a uno muy recomendable (5). Construya:
#
# - Un clasificador usando BERT como extractor de features con estructuras "clásicas". Por ejemplo una regresión logística.
# - Un clasificador usando AutoModelForSequenceClassification.

# %%
# @markdown ❗
# Instalación de librerías
# !pip install -U transformers[torch] --quiet
# !pip install -U tabulate --quiet
# !pip install -U datasets --quiet
# !pip install -U evaluate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.1 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
from datasets import load_dataset
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained('dccuchile/bert-base-spanish-wwm-uncased')
model = AutoModelForMaskedLM.from_pretrained('dccuchile/bert-base-spanish-wwm-uncased',
                                             output_hidden_states=True,use_safetensors=True).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
from datasets import load_dataset
# ============================================
# El dataset "amazon_reviews_multi" tiene reseñas en español.
ds = load_dataset("SetFit/amazon_reviews_multi_es")
# Out:
# README.md:   0%|          | 0.00/310 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# train.jsonl:   0%|          | 0.00/43.8M [00:00<?, ?B/s]
# validation.jsonl: 0.00B [00:00, ?B/s]
# test.jsonl: 0.00B [00:00, ?B/s]
# ...
# Generating test split:   0%|          | 0/5000 [00:00<?, ? examples/s]

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'text', 'label', 'label_text'],
#         num_rows: 200000
#     })
#     validation: Dataset({
#         features: ['id', 'text', 'label', 'label_text'],
#         num_rows: 5000
#     })
#     test: Dataset({
#         features: ['id', 'text', 'label', 'label_text'],
#         num_rows: 5000
#     })
# })

# %%
ds['train'][0]
# Out:
# {'id': 'es_0491108',
#  'text': 'Nada bueno se me fue ka pantalla en menos de 8 meses y no he recibido respuesta del fabricante',
#  'label': 0,
#  'label_text': '0'}

# %% [markdown]
# ## Usando BERT como extractor de features

# %% [markdown]
# ## Usando AutoModelForSequenceClassification
